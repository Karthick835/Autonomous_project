# %% [markdown]
# # Autonomous AI Scientist Reproducible Notebook
# **Dataset Path**: `C:\Users\admin\Desktop\llm and ml project\data\sample_churn.csv`
# **Active Target**: `churned`
# This notebook reproduces all data profiling, hypothesis testing, statistical FDR checks, and model evaluations conducted by the Autonomous AI Scientist engine.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# Load Dataset
df = pd.read_csv('C:/Users/admin/Desktop/llm and ml project/data/sample_churn.csv')
print("Dataset Loaded Successfully. Shape:", df.shape)
df.head()

# %%
# Plot Correlation Matrix Heatmap for Numerical Features
numeric_cols = df.select_dtypes(include=[np.number]).columns
if len(numeric_cols) >= 2:
    plt.figure(figsize=(10, 6))
    sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
    plt.title("Numerical Feature Correlation Matrix", fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()

# %%
# Plot Target Variable Distribution
plt.figure(figsize=(8, 4))
if pd.api.types.is_numeric_dtype(df['churned']) and df['churned'].nunique() > 10:
    sns.histplot(df['churned'].dropna(), kde=True, color='#6366f1')
    plt.title("Target Distribution: churned", fontsize=13, fontweight='bold')
else:
    sns.countplot(x='churned', data=df, palette='viridis')
    plt.title("Target Class Distribution: churned", fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
print("=== CONFIRMED SCIENTIFIC DISCOVERIES ===")
findings = [
  {
    "hypothesis_id": "H001",
    "title": "Age vs Churned Distribution Shift",
    "category": "Group Comparison",
    "status": "CONFIRMED_DISCOVERY",
    "p_value": 1.3966025708653006e-09,
    "fdr_significant": true,
    "effect_size": 4.946091193249742,
    "effect_size_metric": "Cohen's d",
    "summary": "Confirmed relationship between 'age' and 'churned' (p = 0.0000, Cohen's d = 4.946).",
    "details": {
      "group0_mean": 32.32,
      "group1_mean": 61.04,
      "difference": 28.72
    }
  },
  {
    "hypothesis_id": "H002",
    "title": "Tenure_Months vs Churned Distribution Shift",
    "category": "Group Comparison",
    "status": "CONFIRMED_DISCOVERY",
    "p_value": 1.389045600842995e-09,
    "fdr_significant": true,
    "effect_size": 3.103838415042275,
    "effect_size_metric": "Cohen's d",
    "summary": "Confirmed relationship between 'tenure_months' and 'churned' (p = 0.0000, Cohen's d = 3.104).",
    "details": {
      "group0_mean": 38.84,
      "group1_mean": 6.04,
      "difference": -32.800000000000004
    }
  },
  {
    "hypothesis_id": "H003",
    "title": "Monthly_Charges vs Churned Distribution Shift",
    "category": "Group Comparison",
    "status": "CONFIRMED_DISCOVERY",
    "p_value": 1.4156562248495535e-09,
    "fdr_significant": true,
    "effect_size": 2.9468164683296982,
    "effect_size_metric": "Cohen's d",
    "summary": "Confirmed relationship between 'monthly_charges' and 'churned' (p = 0.0000, Cohen's d = 2.947).",
    "details": {
      "group0_mean": 49.21,
      "group1_mean": 95.608,
      "difference": 46.398
    }
  },
  {
    "hypothesis_id": "H004",
    "title": "Independence Check: Contract_Type on Churned",
    "category": "Categorical Independence",
    "status": "CONFIRMED_DISCOVERY",
    "p_value": 9.502101132668301e-11,
    "fdr_significant": true,
    "effect_size": 0.9607689228305227,
    "effect_size_metric": "Cram\u00e9r's V",
    "summary": "Confirmed relationship between 'contract_type' and 'churned' (p = 0.0000, Cram\u00e9r's V = 0.961).",
    "details": {
      "degrees_of_freedom": 2
    }
  },
  {
    "hypothesis_id": "H005",
    "title": "Independence Check: Paperless_Billing on Churned",
    "category": "Categorical Independence",
    "status": "CONFIRMED_DISCOVERY",
    "p_value": 4.138729391000843e-08,
    "fdr_significant": true,
    "effect_size": 0.7756717518813397,
    "effect_size_metric": "Cram\u00e9r's V",
    "summary": "Confirmed relationship between 'paperless_billing' and 'churned' (p = 0.0000, Cram\u00e9r's V = 0.776).",
    "details": {
      "degrees_of_freedom": 1
    }
  },
  {
    "hypothesis_id": "H006",
    "title": "Multi-Feature Machine Learning Model for Churned",
    "category": "Predictive ML",
    "status": "CONFIRMED_DISCOVERY",
    "p_value": 0.0001,
    "fdr_significant": true,
    "effect_size": 1.0,
    "effect_size_metric": "ROC-AUC Score",
    "summary": "Confirmed relationship between 'all_features' and 'churned' (p = 0.0001, ROC-AUC Score = 1.000).",
    "details": {
      "std_score": 0.0,
      "top_features": {
        "tenure_months": 0.18633505300171968,
        "support_tickets": 0.17180997344040821,
        "payment_method_Electronic Check": 0.14825234441602728,
        "monthly_charges": 0.13333333333333333,
        "age": 0.1108602478707947
      }
    }
  }
]
for f in findings:
    if f['status'] == 'CONFIRMED_DISCOVERY':
        print(f"[CONFIRMED] {f['title']} | p={f['p_value']} | {f['effect_size_metric']}={f['effect_size']}")
